# %%
from video_utils import play_video

# Define the path (relative to this notebook's folder) and play it
video_path = None
if video_path:
    play_video(video_path)

# Example video
else:
    play_video()
# Out:
# Stream stopped by user.
