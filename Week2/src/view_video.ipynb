# %%
import os
import sys
from pathlib import Path

# Define week's root as the working directory, while importing scripts correctly
current_dir = Path.cwd()
if current_dir.name == "detection":
    sys.path.insert(0, str(current_dir))
    os.chdir(current_dir.parent.parent.resolve())
    print(f"Execution context anchored at: {os.getcwd()}")
else:
    print(f"Execution context is already correct ({current_dir}).")
# Out:
# Execution context is already correct (/export/home/group01/C5/oriol/mcv-c6-2026-team1/Week2/src).

# %%
from video_utils import play_video

# Define the path (relative to the week root) and play it
video_path = "./tracking_results/test_video.mp4"
if video_path:
    play_video(video_path)

# Original video (with the training frames)
else:
    play_video()
# Out:
# Stream stopped by user.

# %%
from video_utils import extract_video, video_to_gif

name = "original"
video_name = name + ".mp4"
gif_name = name + ".gif"
extract_video(output_path=video_name)
video_to_gif(video_name, gif_name)
# Out:
# Extracting frames 535-935 from data/AICity_data/train/S03/c010/vdo.avi...
# 100%|██████████| 400/400 [00:08<00:00, 49.43it/s]
# Frames successfully saved to 'original.mp4'.
# Converting 'original.mp4' to 'original.gif' at 20 fps...
# Successfully saved GIF to 'original.gif'.
